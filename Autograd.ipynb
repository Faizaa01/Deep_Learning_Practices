# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizaa01/Deep_Learning_Practices/blob/main/Autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

def dy_dx(x):
  return 2*x
dy_dx(2)
# Out:
# 4

# %%
def nested_fun(x):
  return 2*x*torch.cos(x**2)
a = torch.tensor(2.0)
nested_fun(a)
# Out:
# tensor(-2.6146)

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()
x.grad
# Out:
# tensor(4.)

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x**2
z = torch.sin(y)
z
# Out:
# tensor(-0.7568, grad_fn=<SinBackward0>)

# %%
z.backward()
x.grad
# Out:
# tensor(-2.6146)

# %%
x = torch.tensor(2.0)
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

# %%
def binary_cross_entropy(prediction, target):
  epsilon = 1e-8
  prediction = torch.clamp(prediction, epsilon, 1-epsilon)
  return -(target*torch.log(prediction) + (1-target)*torch.log(1-prediction))

# %%
z = w*x+b
y_pred = torch.sigmoid(z)
loss = binary_cross_entropy(y_pred, y)
loss
# Out:
# tensor(2.1269)

# %%
dl_dy_pred = (y_pred-y)/(y_pred*(1-y_pred))
dy_pred_dz = y_pred*(1-y_pred)
dz_dw = x
dz_db = 1

dl_dw = dl_dy_pred * dy_pred_dz * dz_dw
dl_db = dl_dy_pred * dy_pred_dz * dz_db
dl_dw, dl_db
# Out:
# (tensor(1.7616), tensor(0.8808))

# %%
x = torch.tensor(2.0)
y = torch.tensor(0.0)

w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
z = w*x+b
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.8808, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy(y_pred, y)
loss
# Out:
# tensor(2.1269, grad_fn=<NegBackward0>)

# %%
loss.backward()
w.grad, b.grad
# Out:
# (tensor(1.7616), tensor(0.8808))

# %% [markdown]
# Multiple inputs

# %%
x = torch.tensor([1.0,20,3.0], requires_grad=True)
y = (x**2).mean()
x, y
# Out:
# (tensor([ 1., 20.,  3.], requires_grad=True),
#  tensor(136.6667, grad_fn=<MeanBackward0>))

# %%
y.backward()
x.grad
# Out:
# tensor([ 0.6667, 13.3333,  2.0000])

# %%
x.grad.zero_() #to reset the memory
z = x.detach() # to not keep track
